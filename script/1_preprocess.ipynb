# %%
import os
import numpy as np
import pandas as pd
import mne
from pathlib import Path
import logging
from collections import defaultdict

# %%
# == Configuration ==
# === Logging format: timestamp - level - message ===
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# === Paths ===
CURRENT_DIR = Path.cwd()
PATH_DATA_RAW = CURRENT_DIR / "data" / "raw"
PATH_DATA_PROCESSED = CURRENT_DIR / "data" / "processed"
PATH_DATA_PROCESSED.mkdir(parents=True, exist_ok=True)

# === Subject lists ===
SUBJECT_IDS = [f'sub-{i}' for i in [
    1117, 1118, 1120, 
    1124, 1126, 1131, 1132, 1135, 1136,
    1151, 1160, 1164, 1167, 1169, 1172, 1173, 1178,
    1182, 1215, 1216, 1219, 1223, 1227, 1233,
    1234, 1237, 1240, 1243, 1245, 1247, 1250, 1239,
    1252, 1257, 1261, 1265, 1266, 1268, 1270, 1276, 1281
    ]]

# === BIDS labels ===
BIDS_TASK_LABEL_EEG = '_task-dynamic'
BIDS_EEG_SUFFIX = '_eeg'
BIDS_TASK_LABEL_BEH = '_task-MAT'
BIDS_BEH_SUFFIX = '_behavEEG'

# === ERP parameters ===
ERP_TMIN, ERP_TMAX = -0.5, 2
RESP_PRE, RESP_POST = -1, 0.2
BASELINE_TMIN, BASELINE_TMAX = -0.25, 0

# %% [markdown]
# 1 visual inspection for bad channels
#
# 2 preprocessing: resampling, filtering, rereference, ICA
#
# 3 save as BIDS（combine eeg and behvioral data）

# %%
# === Test ===
PATH_PREPROCESS_DATA_BIDS = CURRENT_DIR.parent / 'data' / 'preprocess' 
beh_files = sorted(PATH_PREPROCESS_DATA_BIDS.glob('sub-*/beh/*_beh.csv'))
eeg_files = sorted(PATH_PREPROCESS_DATA_BIDS.glob('sub-*/eeg/*.vhdr'))
beh_by_sub = {p.parent.parent.name: p for p in beh_files}
eeg_by_sub = {p.parent.parent.name: p for p in eeg_files}

for sub_id in SUBJECT_IDS:
    path_eeg = eeg_by_sub[f'{sub_id}']
    path_behavior = beh_by_sub[f'{sub_id}']
    logger.info(f"Processing subject: {sub_id}")

    # === Step 1: load eeg and behavior data ===
    data_behavior = pd.read_csv(path_behavior)
    if 'probe_rt' not in data_behavior.columns:
        logger.warning(f"{sub_id}: rt column missing in behavior, skipping")
        continue
    index_valid_trial = data_behavior[data_behavior['rt_is_not_outlier']].index.to_list()

    raw = mne.io.read_raw_brainvision(path_eeg, preload=True, verbose='ERROR')
    events, event_id = mne.events_from_annotations(raw, verbose='ERROR')

    stim_event_id = {"Stimulus/S  8": 8}
    stim_value =8
    stim_events = events[events[:,2]==stim_value]

    assert len(stim_events) == len(data_behavior), f"{sub_id}: events and data_behavior have different lengths"
    print(f'raw length of data:{len(data_behavior)}')

    # === Step 2: Epoch data ===
    epochs_full = mne.Epochs(
        raw,
        events = stim_events,
        event_id = stim_event_id,
        tmin = ERP_TMIN,
        tmax = ERP_TMAX,
        baseline= (BASELINE_TMIN, BASELINE_TMAX),
        #reject = {"eeg": 200e-5},
        metadata = data_behavior,
        preload = True,
        event_repeated = 'drop',
        verbose='ERROR',
    )

    beh_clean = epochs_full.metadata.reset_index(drop=True)
    print(f'clean beh data:{len(beh_clean)}; epoch data:{len(epochs_full)}')

# test length
epochs_conditions = len(epochs_full["cue_dimensionality == 4"])
behavior_conditions = len(data_behavior[data_behavior['cue_dimensionality'] == 4])
print(f'epochs_conditions: {epochs_conditions}; behavior_condition: {behavior_conditions}')
# Out:
# 2026-05-30 14:07:34,583 - INFO - Processing subject: sub-1117
# 2026-05-30 14:07:35,475 - INFO - Processing subject: sub-1118
# raw length of data:256
# clean beh data:256; epoch data:256
# 2026-05-30 14:07:36,312 - INFO - Processing subject: sub-1120
# raw length of data:256
# clean beh data:256; epoch data:256
# raw length of data:256
# clean beh data:256; epoch data:256
# epochs_conditions: 64; behavior_condition: 64

# %%
# Prepare data for plotting
PATH_PREPROCESS_DATA_BIDS = CURRENT_DIR.parent / 'data' / 'preprocess' 
PATH_PREPROCESS_DATA_BIDS = Path('/Users/hyijie/Desktop/CPP_local_own/3_Data/preprocessData/CPP_low-level-2_Kosciessa_et_al_2021')
beh_files = sorted(PATH_PREPROCESS_DATA_BIDS.glob('sub-*/beh/*_beh.csv'))
eeg_files = sorted(PATH_PREPROCESS_DATA_BIDS.glob('sub-*/eeg/*.vhdr'))
beh_by_sub = {p.parent.parent.name: p for p in beh_files}
eeg_by_sub = {p.parent.parent.name: p for p in eeg_files}

# 存每个 cue_dimensionality 条件下，每个被试的 ERP
erp_by_conditions = defaultdict(list)

for sub_id in SUBJECT_IDS:
    path_eeg = eeg_by_sub[f'{sub_id}']
    path_behavior = beh_by_sub[f'{sub_id}']
    logger.info(f"Processing subject: {sub_id}")

    # === Step 1: load eeg and behavior data ===
    data_behavior = pd.read_csv(path_behavior)
    if 'probe_rt' not in data_behavior.columns:
        logger.warning(f"{sub_id}: rt column missing in behavior, skipping")
        continue
    index_valid_trial = data_behavior[data_behavior['rt_is_not_outlier']].index.to_list()

    raw = mne.io.read_raw_brainvision(path_eeg, preload=True, verbose='ERROR')
    events, event_id = mne.events_from_annotations(raw, verbose='ERROR')

    stim_event_id = {"Stimulus/S  8": 8}
    stim_value =8
    stim_events = events[events[:,2]==stim_value]

    assert len(stim_events) == len(data_behavior), f"{sub_id}: events and data_behavior have different lengths"
    print(f'raw length of data:{len(data_behavior)}')

    # === Step 2: Epoch data ===
    epochs_full = mne.Epochs(
        raw,
        events = stim_events,
        event_id = stim_event_id,
        tmin = ERP_TMIN,
        tmax = ERP_TMAX,
        baseline= (BASELINE_TMIN, BASELINE_TMAX),
        #reject = {"eeg": 200e-5},
        metadata = data_behavior,
        preload = True,
        event_repeated = 'drop',
        verbose='ERROR',
    )

    for con in [1, 2, 3, 4]:
        epochs_condition = epochs_full[f"cue_dimensionality ==  {con}"]
        evoked_condition = epochs_condition.average()#.get_data()
        erp_by_conditions[con].append(evoked_condition)

evokeds_for_plot = {
    f"cue_dimensionality={con}": erp_list
    for con, erp_list in erp_by_conditions.items()
}

CPP_CHANNELS = ["POz"]

mne.viz.plot_compare_evokeds(
    evokeds_for_plot,
    picks=CPP_CHANNELS,
    combine="mean",
    ci=True,
    show=True
)
# Out:
# 2026-05-30 14:17:54,481 - INFO - Processing subject: sub-1117
# raw length of data:256
# 2026-05-30 14:17:55,512 - INFO - Processing subject: sub-1118
# raw length of data:256
# 2026-05-30 14:17:56,616 - INFO - Processing subject: sub-1120
# raw length of data:256
# 2026-05-30 14:17:57,598 - INFO - Processing subject: sub-1124
# raw length of data:256
# 2026-05-30 14:17:58,484 - INFO - Processing subject: sub-1126
# raw length of data:256
# 2026-05-30 14:17:59,347 - INFO - Processing subject: sub-1131
# raw length of data:256
# 2026-05-30 14:18:00,223 - INFO - Processing subject: sub-1132
# raw length of data:256
# 2026-05-30 14:18:01,209 - INFO - Processing subject: sub-1135
# raw length of data:256
# 2026-05-30 14:18:02,170 - INFO - Processing subject: sub-1136
# raw length of data:256
# 2026-05-30 14:18:03,023 - INFO - Processing subject: sub-1151
# raw length of data:256
# 2026-05-30 14:18:03,902 - INFO - Processing subject: sub-1160
# raw length of data:256
# 2026-05-30 14:18:04,745 - INFO - Processing subject: sub-1164
# raw length of data:256
# 2026-05-30 14:18:05,620 - INFO - Processing subject: sub-1167
# raw length of data:256
# 2026-05-30 14:18:06,929 - INFO - Processing subject: sub-1169
# raw length of data:256
# 2026-05-30 14:18:08,114 - INFO - Processing subject: sub-1172
# raw length of data:256
# 2026-05-30 14:18:09,306 - INFO - Processing subject: sub-1173
# raw length of data:256
# 2026-05-30 14:18:10,407 - INFO - Processing subject: sub-1178
# raw length of data:256
# 2026-05-30 14:18:11,416 - INFO - Processing subject: sub-1182
# raw length of data:256
# 2026-05-30 14:18:12,365 - INFO - Processing subject: sub-1215
# raw length of data:256
# 2026-05-30 14:18:13,274 - INFO - Processing subject: sub-1216
# raw length of data:256
# 2026-05-30 14:18:14,218 - INFO - Processing subject: sub-1219
# raw length of data:256
# 2026-05-30 14:18:15,199 - INFO - Processing subject: sub-1223
# raw length of data:256
# 2026-05-30 14:18:16,098 - INFO - Processing subject: sub-1227
# raw length of data:256
# 2026-05-30 14:18:17,037 - INFO - Processing subject: sub-1233
# raw length of data:256
# 2026-05-30 14:18:17,977 - INFO - Processing subject: sub-1234
# raw length of data:256
# 2026-05-30 14:18:18,983 - INFO - Processing subject: sub-1237
# raw length of data:256
# 2026-05-30 14:18:20,003 - INFO - Processing subject: sub-1240
# raw length of data:256
# 2026-05-30 14:18:20,915 - INFO - Processing subject: sub-1243
# raw length of data:256
# 2026-05-30 14:18:21,772 - INFO - Processing subject: sub-1245
# raw length of data:256
# 2026-05-30 14:18:22,706 - INFO - Processing subject: sub-1247
# raw length of data:256
# 2026-05-30 14:18:23,612 - INFO - Processing subject: sub-1250
# raw length of data:256
# 2026-05-30 14:18:24,486 - INFO - Processing subject: sub-1239
# raw length of data:256
# 2026-05-30 14:18:25,340 - INFO - Processing subject: sub-1252
# raw length of data:256
# 2026-05-30 14:18:26,178 - INFO - Processing subject: sub-1257
# raw length of data:256
# 2026-05-30 14:18:27,102 - INFO - Processing subject: sub-1261
# raw length of data:256
# 2026-05-30 14:18:28,006 - INFO - Processing subject: sub-1265
# raw length of data:256
# 2026-05-30 14:18:28,944 - INFO - Processing subject: sub-1266
# raw length of data:256
# 2026-05-30 14:18:29,829 - INFO - Processing subject: sub-1268
# raw length of data:256
# 2026-05-30 14:18:30,694 - INFO - Processing subject: sub-1270
# raw length of data:256
# 2026-05-30 14:18:31,576 - INFO - Processing subject: sub-1276
# raw length of data:256
# 2026-05-30 14:18:32,438 - INFO - Processing subject: sub-1281
# raw length of data:256
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# /var/folders/xc/16fqwx1n1gbfb77yd1bdg8mh0000gn/T/ipykernel_5881/23927832.py:61: RuntimeWarning: Only 1 channel in "picks"; cannot combine by method "mean".
#   mne.viz.plot_compare_evokeds(
# /var/folders/xc/16fqwx1n1gbfb77yd1bdg8mh0000gn/T/ipykernel_5881/23927832.py:61: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   mne.viz.plot_compare_evokeds(
# [<Figure size 800x600 with 1 Axes>]
